# %%
# !unzip /content/drive/MyDrive/2752.zip

# %%
# !pip install ultralytics
from ultralytics import YOLO

# %%
model=YOLO('yolov8n-cls')

# %%
history = model.train(data='/content/drive/MyDrive/2752',epochs=5,imgsz=64)
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
