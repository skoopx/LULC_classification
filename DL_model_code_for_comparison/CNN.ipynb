# %%
import os
import shutil
import random
from tqdm import tqdm

import numpy as np
import pandas as pd

import PIL
import seaborn as sns
import matplotlib.pyplot as plt

# %%
DATASET = "2750"

# List directories within the dataset directory
folders = [f for f in os.listdir(DATASET) if os.path.isdir(os.path.join(DATASET, f))]

# Print the folders
print("Folders in the dataset directory:")
for folder in folders:
    print(folder)
# Out:
# Folders in the dataset directory:
# AnnualCrop
# Forest
# HerbaceousVegetation
# Highway
# Industrial
# Pasture
# PermanentCrop
# Residential
# River
# SeaLake

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

DATASET_DIR = "2750"

IMG_WIDTH, IMG_HEIGHT = 64, 64
BATCH_SIZE = 32

datagen = ImageDataGenerator(
    rescale=1./255,  # Normalize pixel values to [0, 1]
    validation_split=0.2  # Split dataset into training and validation sets
)
# Out:
# WARNING:tensorflow:From c:\Users\Sudeesh Kumar V\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
train_generator = datagen.flow_from_directory(
    DATASET_DIR,
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    DATASET_DIR,
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 21600 images belonging to 10 classes.
# Found 5400 images belonging to 10 classes.

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(len(train_generator.class_indices), activation='softmax')
])
# Out:
# WARNING:tensorflow:From c:\Users\Sudeesh Kumar V\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\Sudeesh Kumar V\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // BATCH_SIZE,
    epochs=10,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // BATCH_SIZE
)
# Out:
# WARNING:tensorflow:From c:\Users\Sudeesh Kumar V\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# WARNING:tensorflow:From c:\Users\Sudeesh Kumar V\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Sudeesh Kumar V\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 675/675 [==============================] - 35s 50ms/step - loss: 1.3277 - accuracy: 0.4828 - val_loss: 0.9103 - val_accuracy: 0.6644
# Epoch 2/10
# 675/675 [==============================] - 18s 27ms/step - loss: 0.8463 - accuracy: 0.6956 - val_loss: 0.6930 - val_accuracy: 0.7556
# Epoch 3/10
# 675/675 [==============================] - 19s 29ms/step - loss: 0.6784 - accuracy: 0.7541 - val_loss: 0.7253 - val_accuracy: 0.7407
# Epoch 4/10
# 675/675 [==============================] - 56s 83ms/step - loss: 0.6039 - accuracy: 0.7816 - val_loss: 0.6139 - val_accuracy: 0.7894
# Epoch 5/10
# 675/675 [==============================] - 60s 88ms/step - loss: 0.5382 - accuracy: 0.8083 - val_loss: 0.5352 - val_accuracy: 0.8108
# Epoch 6/10
# 675/675 [==============================] - 65s 97ms/step - loss: 0.4725 - accuracy: 0.8308 - val_loss: 0.5197 - val_accuracy: 0.8136
# Epoch 7/10
# 675/675 [==============================] - 63s 94ms/step - loss: 0.4449 - accuracy: 0.8440 - val_loss: 0.5062 - val_accuracy: 0.8237
# Epoch 8/10
# 675/675 [==============================] - 59s 88ms/step - loss: 0.3898 - accuracy: 0.8625 - val_loss: 0.5136 - val_accuracy: 0.8203
# Epoch 9/10
# 675/675 [==============================] - 53s 79ms/step - loss: 0.3522 - accuracy: 0.8742 - val_loss: 0.5280 - val_accuracy: 0.8186
# Epoch 10/10
# 675/675 [==============================] - 61s 91ms/step - loss: 0.3122 - accuracy: 0.8903 - val_loss: 0.4844 - val_accuracy: 0.8331
